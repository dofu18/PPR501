# %%
def tong(n):
    if n > 0 and is_integer(n, int):
        s = 0
        for i in range(1, n + 1):
            s += i/i+1
        return s
    else:
        return "Nhap sai n"

# %%
tong(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tong(5)
#
# Cell In[1], line 2, in tong(n)
#       1 def tong(n):
# ----> 2     if n > 0 and is_integer(n, int):
#       3         s = 0
#       4         for i in range(1, n + 1):
#
# NameError: name 'is_integer' is not defined

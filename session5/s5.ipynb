# %% [markdown]
# # PANDAS

# %%
import pandas as pd 

df = pd.read_csv('S9_brics.csv')
print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv('S9_brics.csv')
#       4 print(df)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import pandas as pd

df = pd.read_csv('S9_brics.csv')
df.head()

# %%
import pandas as pd

df = pd.read_csv('S9_brics.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
import pandas as pd 

df = pd.read_csv('S9_brics.csv')
new_df = df.drop(["area", "population"], axis=1)
print(new_df)

df_new1 = df.drop([1], axis=0).reset_index(drop=True)
print(df_new1)

# %%
import pandas as pd

data = {
    'A': [1, 2, 3, 4],
    'B': [5, 6, 7, 8],
}
df = pd.DataFrame(data)

# print(df)

def sum_rows(row):
    return row.sum()    

result = df.apply(sum_rows, axis=1)
print(result)

# %%
import pandas as pd

df = pd.read_csv('S9_brics.csv')

df['density'] = df['population'] / df['area'] * 10000000
print(df)

# %%
import pandas as pd

df = pd.read_csv('S9_brics.csv')

new_value = df['population'] / df['area'] * 10000000
df.insert(0, 'density', new_value)
print(df)

# %%
df.iloc[2, 3] = "DoPhu"
print(df)

# %%
new_row = pd.DataFrame({
    "country": "NewCountry",
    "area": 123456,
    "population": 7890123,
    "Unnamed: 0": "VN",
    "density": 64.0,
    "capital": "NewCapital"
},index=["x"])

df_new = pd.concat([df, new_row], ignore_index=True)
print(df_new)

# %%
import pandas as pd
student_df = pd.read_csv('student.csv')

student_df.info()

# %%
student_df.fillna(student_df["english.grade"].mean(), inplace=True)
student_df.head()
# student_df.info()
student_df.isna()

# %% [markdown]
# # IMAGE DATA

# %%
import cv2

data =  cv2.imread('nature.png', 1)

cv2.imwrite('processed_nature.png', data)
# Out:
# True

# %%
import matplotlib.pyplot as plt
img = cv2.imread('nature.png', -1)   

plt.imshow(img, cmap='gray')
plt.axis('off')
plt.show()

# %%
def rescale_frame(frame, scale=0.5):
    width = int(frame.shape[1] * scale)
    height = int(frame.shape[0] * scale)
    dimensions = (width, height)
    return cv2.resize(frame, (width, height))

rescale_img = rescale_frame(img, scale=0.5)
cv2.imshow("text",rescale_img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       4     dimensions = (width, height)
#       5     return cv2.resize(frame, (width, height))
# ----> 7 rescale_img = rescale_frame(img, scale=0.5)
#       8 cv2.imshow("text",rescale_img)
#       9 cv2.waitKey(0)
#
# NameError: name 'img' is not defined

# %%
plt.imshow(rescale_img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.imshow(rescale_img)
#       2 plt.show()
#
# NameError: name 'plt' is not defined
